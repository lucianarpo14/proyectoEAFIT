# %%
import pandas as pd

# %%
#data = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-4/master/CaseStudy/Attrition.csv')
data = pd.read_excel('C:/Users/Luciana Restrepo/OneDrive/Documentos/EAFIT/Caso1.xlsx')

# %%
data
# Out:
#        Consecutivo Documento Deudor     Nit  Nombres  Numero Documento  \
# 0                          28768192      18      NaN               NaN
# 1                           2712044      22      NaN               NaN
# 2                          13587837      23      NaN               NaN
# 3                          23479925      46      NaN               NaN
# 4                           2712382      92      NaN               NaN
# ...                             ...     ...      ...               ...
# 89242                      24892452  787457      NaN               NaN
# 89243                      24485118  787459      NaN               NaN
# 89244                      27364653  787459      NaN               NaN
# 89245                      28482366  787459      NaN               NaN
# 89246                      27641335  787459      NaN               NaN
#
#        Tipo De Producto             PRODUCTO  Valor Obligacion  Valor Vencido  \
# 0                     3  TARJETAS DE CREDITO         5637605.0       152093.0
# 1                     5              CONSUMO           40584.0        40584.0
# 2                     3  TARJETAS DE CREDITO         2786178.0       547088.0
# 3                     3  TARJETAS DE CREDITO         5904653.0      1455631.0
# 4                     5              CONSUMO         2221125.0      2221125.0
# ...                 ...                  ...               ...            ...
# 89242                89              CONSUMO         2048599.0       284377.0
# 89243                 4              CONSUMO        33835903.0      2790040.0
# 89244                88              CONSUMO         1540300.0      1511822.0
# 89245                88              CONSUMO         3954718.0       609495.0
# 89246                88              CONSUMO         2172488.0       350295.0
#
#        Regional  REGION  ...  Red                                  Cuadrante  \
# 0          2099  BOGOTA  ...    1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 1          2099  BOGOTA  ...    1                              SIN CUADRANTE
# 2          3099     SUR  ...    1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 3          2099  BOGOTA  ...    1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
# 4          6399  CENTRO  ...    1           TIENE VOLUNTAD Y TIENE CAPACIDAD
# ...         ...     ...  ...  ...                                        ...
# 89242      3099     SUR  ...    1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 89243      3099     SUR  ...    1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
# 89244      3099     SUR  ...    1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
# 89245      3099     SUR  ...    1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
# 89246      3099     SUR  ...    1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
#
#                       Descripcion Causal Calificacion Real  \
# 0                              CALAMIDAD                 2
# 1                     SIN CAUSAL DE MORA                 3
# 2             RETRASO EN PAGO DE SALARIO                 1
# 3                               DESCUIDO                 1
# 4                               DESCUIDO                 2
# ...                                  ...               ...
# 89242                           DESCUIDO                 3
# 89243  DESEMPLEADO TITULAR Y/O COTITULAR                 3
# 89244  DESEMPLEADO TITULAR Y/O COTITULAR                 3
# 89245  DESEMPLEADO TITULAR Y/O COTITULAR                 3
# 89246  DESEMPLEADO TITULAR Y/O COTITULAR                 3
#
#       Fecha De Perfeccionamiento Endeudamiento  Rango endeudamiento  \
# 0                     1978-12-06    5637605.00  2015-01-01 00:00:00
# 1                     2015-03-11      40584.00                  <1M
# 2                     2003-03-27    7747280.00  2015-01-01 00:00:00
# 3                     1990-09-01    5904653.00  2015-01-01 00:00:00
# 4                     2015-05-12    2221125.00  2015-01-01 00:00:00
# ...                          ...           ...                  ...
# 89242                 2013-05-27   37088351.03                15-50
# 89243                 2013-03-18   45757681.00                15-50
# 89244                 2014-06-03   45757681.00                15-50
# 89245                 2014-09-29   45757681.00                15-50
# 89246                 2014-07-22   45757681.00                15-50
#
#        Sector Economico      Profesion                Ocupacion
# 0                   NaN  SIN PROFESION               SIN OFICIO
# 1                   NaN  SIN PROFESION               SIN OFICIO
# 2                   NaN  SIN PROFESION                 JUBILADO
# 3                   NaN  SIN PROFESION               SIN OFICIO
# 4          AGROPECUARIO     AGRICULTOR                  TAXISTA
# ...                 ...            ...                      ...
# 89242         EDUCACION       PROFESOR  EMPLEADO SECTOR PUBLICO
# 89243               NaN  SIN PROFESION               SIN OFICIO
# 89244               NaN  SIN PROFESION               SIN OFICIO
# 89245               NaN  SIN PROFESION               SIN OFICIO
# 89246               NaN  SIN PROFESION               SIN OFICIO
#
# [89247 rows x 27 columns]

# %%
data.head(20)
# Out:
#     Consecutivo Documento Deudor  Nit  Nombres  Numero Documento  \
# 0                       28768192   18      NaN               NaN
# 1                        2712044   22      NaN               NaN
# 2                       13587837   23      NaN               NaN
# 3                       23479925   46      NaN               NaN
# 4                        2712382   92      NaN               NaN
# 5                        1683416  104      NaN               NaN
# 6                        4270407  106      NaN               NaN
# 7                       21947686  119      NaN               NaN
# 8                        2712477  120      NaN               NaN
# 9                       19927288  129      NaN               NaN
# 10                      27276578  156      NaN               NaN
# 11                      24078684  178      NaN               NaN
# 12                      27276891  224      NaN               NaN
# 13                      22239451  252      NaN               NaN
# 14                      25865935  277      NaN               NaN
# 15                      20431067  291      NaN               NaN
# 16                       1930041  306      NaN               NaN
# 17                      29240426  306      NaN               NaN
# 18                      21362395  310      NaN               NaN
# 19                      17682668  310      NaN               NaN
#
#     Tipo De Producto             PRODUCTO  Valor Obligacion  Valor Vencido  \
# 0                  3  TARJETAS DE CREDITO         5637605.0       152093.0
# 1                  5              CONSUMO           40584.0        40584.0
# 2                  3  TARJETAS DE CREDITO         2786178.0       547088.0
# 3                  3  TARJETAS DE CREDITO         5904653.0      1455631.0
# 4                  5              CONSUMO         2221125.0      2221125.0
# 5                  3  TARJETAS DE CREDITO          610840.0       349729.0
# 6                  3  TARJETAS DE CREDITO         1527464.0      1527464.0
# 7                  3  TARJETAS DE CREDITO         4310924.0      1239257.0
# 8                  5              CONSUMO         1110042.0      1110042.0
# 9                  3  TARJETAS DE CREDITO         5228504.0       547011.0
# 10                 3  TARJETAS DE CREDITO         5565488.0       882256.0
# 11                 6              CONSUMO         3846462.0       148001.0
# 12                 3  TARJETAS DE CREDITO          874684.0       874684.0
# 13                 3  TARJETAS DE CREDITO         3056330.0       584128.0
# 14                 3  TARJETAS DE CREDITO         1449341.0       125650.0
# 15                 3  TARJETAS DE CREDITO         4249842.0      4249842.0
# 16                 3  TARJETAS DE CREDITO         2985123.0       240968.0
# 17                 3  TARJETAS DE CREDITO          671155.0        74622.0
# 18                 3  TARJETAS DE CREDITO         9798237.0      3187717.0
# 19                 4              CONSUMO        20167562.0      5764921.0
#
#     Regional     REGION  ...  Red                                  Cuadrante  \
# 0       2099     BOGOTA  ...    1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 1       2099     BOGOTA  ...    1                              SIN CUADRANTE
# 2       3099        SUR  ...    1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 3       2099     BOGOTA  ...    1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
# 4       6399     CENTRO  ...    1           TIENE VOLUNTAD Y TIENE CAPACIDAD
# 5       4599     CARIBE  ...    1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
# 6       1099  ANTIOQUIA  ...    1           TIENE VOLUNTAD Y TIENE CAPACIDAD
# 7       2099     BOGOTA  ...    1           TIENE VOLUNTAD Y TIENE CAPACIDAD
# 8       6199     CENTRO  ...    1           TIENE VOLUNTAD Y TIENE CAPACIDAD
# 9       3099        SUR  ...    1           TIENE VOLUNTAD Y TIENE CAPACIDAD
# 10      1099  ANTIOQUIA  ...    1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 11      2099     BOGOTA  ...    1                              SIN CUADRANTE
# 12      2099     BOGOTA  ...    1                              SIN CUADRANTE
# 13      2099     BOGOTA  ...    1                              SIN CUADRANTE
# 14      3099        SUR  ...    1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 15      2099     BOGOTA  ...    1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 16      2099     BOGOTA  ...    1           TIENE VOLUNTAD Y TIENE CAPACIDAD
# 17      2099     BOGOTA  ...    1           TIENE VOLUNTAD Y TIENE CAPACIDAD
# 18      2099     BOGOTA  ...    1           TIENE VOLUNTAD Y TIENE CAPACIDAD
# 19      2099     BOGOTA  ...    1           TIENE VOLUNTAD Y TIENE CAPACIDAD
#
#                      Descripcion Causal Calificacion Real  \
# 0                             CALAMIDAD                 2
# 1                    SIN CAUSAL DE MORA                 3
# 2            RETRASO EN PAGO DE SALARIO                 1
# 3                              DESCUIDO                 1
# 4                              DESCUIDO                 2
# 5                INGRESOS INSUFICIENTES                 0
# 6                              DESCUIDO                 1
# 7                              DESCUIDO                 1
# 8                INGRESOS INSUFICIENTES                 1
# 9                 EXTRACTO NO ENTREGADO                 1
# 10  DISMINUCION DE SALARIO y/o INGRESOS                 2
# 11                             DESCUIDO                 2
# 12                   SIN CAUSAL DE MORA                 2
# 13                   SIN CAUSAL DE MORA                 1
# 14                   RECLAMO EN TRAMITE                 1
# 15               INGRESOS INSUFICIENTES                 2
# 16                             DESCUIDO                 2
# 17                             DESCUIDO                 2
# 18                   CUENTAS POR COBRAR                 3
# 19                   CUENTAS POR COBRAR                 3
#
#    Fecha De Perfeccionamiento Endeudamiento  Rango endeudamiento  \
# 0                  1978-12-06     5637605.0  2015-01-01 00:00:00
# 1                  2015-03-11       40584.0                  <1M
# 2                  2003-03-27     7747280.0  2015-01-01 00:00:00
# 3                  1990-09-01     5904653.0  2015-01-01 00:00:00
# 4                  2015-05-12     2221125.0  2015-01-01 00:00:00
# 5                  1972-10-01      610840.0                  <1M
# 6                  2004-12-03     1574242.0  2015-01-01 00:00:00
# 7                  1998-08-27     4310924.0  2015-01-01 00:00:00
# 8                  2015-06-10     8878707.0  2015-01-01 00:00:00
# 9                  2011-04-29    13101168.0  2015-01-01 00:00:00
# 10                 2014-05-16     5565488.0  2015-01-01 00:00:00
# 11                 2013-01-09     3846462.0  2015-01-01 00:00:00
# 12                 2014-05-16      874684.0                  <1M
# 13                 2008-11-14     3056330.0  2015-01-01 00:00:00
# 14                 2013-10-09     6654086.0  2015-01-01 00:00:00
# 15                 2010-03-16     4277895.0  2015-01-01 00:00:00
# 16                 2003-06-06     4502557.0  2015-01-01 00:00:00
# 17                 2001-04-03     4502557.0  2015-01-01 00:00:00
# 18                 1994-09-01    48463046.0                15-50
# 19                 2011-03-18    48463046.0                15-50
#
#                                      Sector Economico      Profesion  \
# 0                                                 NaN  SIN PROFESION
# 1                                                 NaN  SIN PROFESION
# 2                                                 NaN  SIN PROFESION
# 3                                                 NaN  SIN PROFESION
# 4                                        AGROPECUARIO     AGRICULTOR
# 5                             MADERAS Y SUS PRODUCTOS       CONTADOR
# 6                             TEXTILES Y CONFECCIONES  ADMINISTRADOR
# 7                                                 NaN  SIN PROFESION
# 8   CONSTRUCCION, CEMENTO Y ACTIVIDADES INMOBILIARIAS  SIN PROFESION
# 9                                                 NaN  SIN PROFESION
# 10                                                NaN  SIN PROFESION
# 11                                                NaN  SIN PROFESION
# 12                                                NaN  SIN PROFESION
# 13                                                NaN  SIN PROFESION
# 14                                                NaN  SIN PROFESION
# 15                              SERVICIOS FINANCIEROS       PROFESOR
# 16                                 SERVICIOS PUBLICOS  ADMINISTRADOR
# 17                                 SERVICIOS PUBLICOS  ADMINISTRADOR
# 18                                                NaN  SIN PROFESION
# 19                                                NaN  SIN PROFESION
#
#         Ocupacion
# 0      SIN OFICIO
# 1      SIN OFICIO
# 2        JUBILADO
# 3      SIN OFICIO
# 4         TAXISTA
# 5      SIN OFICIO
# 6      SIN OFICIO
# 7      SIN OFICIO
# 8   INDEPENDIENTE
# 9      SIN OFICIO
# 10     SIN OFICIO
# 11     SIN OFICIO
# 12     SIN OFICIO
# 13     SIN OFICIO
# 14     SIN OFICIO
# 15  INDEPENDIENTE
# 16       JUBILADO
# 17       JUBILADO
# 18     SIN OFICIO
# 19     SIN OFICIO
#
# [20 rows x 27 columns]

# %%
data.describe()
# Out:
#        Consecutivo Documento Deudor            Nit  Nombres  Numero Documento  \
# count                  8.924700e+04   89247.000000      0.0               0.0
# mean                   2.315528e+07  485493.689771      NaN               NaN
# std                    7.479098e+06  271437.508819      NaN               NaN
# min                    7.758000e+03      18.000000      NaN               NaN
# 25%                    2.206810e+07  198392.500000      NaN               NaN
# 50%                    2.578647e+07  563959.000000      NaN               NaN
# 75%                    2.827977e+07  740818.500000      NaN               NaN
# max                    3.016075e+07  787459.000000      NaN               NaN
#
#        Tipo De Producto  Valor Obligacion  Valor Vencido      Regional  \
# count      89247.000000      8.924700e+04   8.924700e+04  89247.000000
# mean          11.400697      7.069210e+06   7.062807e+05   3589.738725
# std           23.431341      1.519014e+07   1.878659e+06   2322.490842
# min            1.000000      1.804400e+04   2.001000e+04      0.000000
# 25%            3.000000      7.655165e+05   1.042480e+05   2099.000000
# 50%            3.000000      1.927124e+06   2.419370e+05   2099.000000
# 75%            4.000000      5.812533e+06   6.112845e+05   5499.000000
# max           94.000000      6.713357e+08   1.831087e+08   8799.000000
#
#              Abogado     Dias Mora  Oficina Radicacion           Red  \
# count   89247.000000  89247.000000        89247.000000  89247.000000
# mean   109977.545105     47.099320          443.386265      1.298688
# std         1.298881     70.105525          302.484171      0.639455
# min    109970.000000      1.000000            0.000000      1.000000
# 25%    109978.000000     26.000000          174.000000      1.000000
# 50%    109978.000000     30.000000          426.000000      1.000000
# 75%    109978.000000     46.000000          710.000000      1.000000
# max    109978.000000   2175.000000          999.000000      3.000000
#
#        Calificacion Real  Endeudamiento
# count       89247.000000   8.924700e+04
# mean            1.721660   1.432068e+07
# std             0.921855   2.916728e+07
# min             0.000000   1.804400e+04
# 25%             1.000000   1.292230e+06
# 50%             2.000000   4.600062e+06
# 75%             2.000000   1.697418e+07
# max             3.000000   2.012549e+09

# %%
data.dtypes
# Out:
# Consecutivo Documento Deudor             int64
# Nit                                      int64
# Nombres                                float64
# Numero Documento                       float64
# Tipo De Producto                         int64
# PRODUCTO                                object
# Valor Obligacion                       float64
# Valor Vencido                          float64
# Regional                                 int64
# REGION                                  object
# Abogado                                  int64
# Dias Mora                                int64
# FRANJA                                  object
# Fecha Traslado Para Cobro       datetime64[ns]
# Fecha Ultima Facturacion                object
# Segmento                                object
# Oficina Radicacion                       int64
# Red                                      int64
# Cuadrante                               object
# Descripcion Causal                      object
# Calificacion Real                        int64
# Fecha De Perfeccionamiento      datetime64[ns]
# Endeudamiento                          float64
# Rango endeudamiento                     object
# Sector Economico                        object
# Profesion                               object
# Ocupacion                               object
# dtype: object

# %%
print('Promedio: ' + str(data['Valor Obligacion'].mean()))
print('Mediana: ' + str(data['Valor Obligacion'].median()))
print('Moda: ' + str(data['Valor Obligacion'].mode()))
# Out:
# Promedio: 7069209.776261833
# Mediana: 1927124.0
# Moda: 0    46869.0
# dtype: float64

# %%
print('Promedio: ' + str(data['Dias Mora'].mean()))
print('Mediana: ' + str(data['Dias Mora'].median()))
print('Moda: ' + str(data['Dias Mora'].mode()))
# Out:
# Promedio: 47.099319865093506
# Mediana: 30.0
# Moda: 0    30
# dtype: int64

# %%
data.Profesion.value_counts()
# Out:
# SIN PROFESION                   57401
# ADMINISTRADOR                    3773
# INGENIERO                        3426
# TECNICO  EXPERTO                 3119
# NO APLICA AL TIPO DE CLIENTE     2829
#                                 ...
# ASTRONOMO                           3
# EMPLEADO                            2
# FILOSOFO                            2
# BOTANICO                            1
# ETNOGRAFO                           1
# Name: Profesion, Length: 85, dtype: int64

# %%
data.PRODUCTO.value_counts()
# Out:
# TARJETAS DE CREDITO    51864
# CONSUMO                19624
# CH PROPIA               8720
# VEHICULOS SUFI          5957
# MASIVO SUFI             2942
# CH TITU                  140
# Name: PRODUCTO, dtype: int64

# %%
data["Tipo De Producto"].value_counts()
# Out:
# 3     51864
# 4      9232
# 2      8720
# 16     5889
# 88     4314
# 5      2118
# 6      1956
# 89     1551
# 20     1511
# 94      890
# 86      440
# 25      268
# 1       140
# 47       83
# 46       79
# 27       68
# 15       50
# 45       29
# 80       26
# 85        7
# 87        6
# 14        3
# 24        3
# Name: Tipo De Producto, dtype: int64

# %%
data.Ocupacion.value_counts()
# Out:
# SIN OFICIO                   56332
# EMPLEADO SECTOR PRIVADO      14473
# INDEPENDIENTE                11554
# EMPLEADO SECTOR PUBLICO       4831
# JUBILADO                       929
# NO APLICA A ESTE PRODUCTO      667
# AMA DE CASA                     86
# TRABAJADOR OFICIAL              74
# TAXISTA                         64
# EMPLEADO FILIAL                 42
# EMPLEADO BANCOLOMBIA            10
# Name: Ocupacion, dtype: int64

# %%
data[data["Ocupacion"]=="SIN OFICIO"]["Valor Obligacion"].plot(kind="kde")
data[data["Ocupacion"]=="INDEPENDIENTE"]["Valor Obligacion"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data[data["Ocupacion"]=="SIN OFICIO"]["Tipo De Producto"].plot(kind="kde")
data[data["Ocupacion"]=="INDEPENDIENTE"]["Tipo De Producto"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
pd.crosstab(data["PRODUCTO"],data["Ocupacion"],margins=True)
# Out:
# Ocupacion            AMA DE CASA  EMPLEADO BANCOLOMBIA  EMPLEADO FILIAL  \
# PRODUCTO
# CH PROPIA                     19                     0                4
# CH TITU                        0                     0                0
# CONSUMO                       12                     2                4
# MASIVO SUFI                    4                     2               14
# TARJETAS DE CREDITO           43                     6               11
# VEHICULOS SUFI                 8                     0                9
# All                           86                    10               42
#
# Ocupacion            EMPLEADO SECTOR PRIVADO  EMPLEADO SECTOR PUBLICO  \
# PRODUCTO
# CH PROPIA                               1685                      686
# CH TITU                                   12                       10
# CONSUMO                                 2770                      887
# MASIVO SUFI                              653                      166
# TARJETAS DE CREDITO                     8302                     2674
# VEHICULOS SUFI                          1051                      408
# All                                    14473                     4831
#
# Ocupacion            INDEPENDIENTE  JUBILADO  NO APLICA A ESTE PRODUCTO  \
# PRODUCTO
# CH PROPIA                     1686        85                        144
# CH TITU                         61         4                          4
# CONSUMO                       3219       345                        141
# MASIVO SUFI                    346        17                         27
# TARJETAS DE CREDITO           4848       422                        292
# VEHICULOS SUFI                1394        56                         59
# All                          11554       929                        667
#
# Ocupacion            SIN OFICIO  TAXISTA  TRABAJADOR OFICIAL    All
# PRODUCTO
# CH PROPIA                  4331       18                  11   8669
# CH TITU                      49        0                   0    140
# CONSUMO                   12187       18                   8  19593
# MASIVO SUFI                1703        1                   6   2939
# TARJETAS DE CREDITO       35116       25                  29  51768
# VEHICULOS SUFI             2946        2                  20   5953
# All                       56332       64                  74  89062

# %%
pd.crosstab(data["Tipo De Producto"],data["PRODUCTO"],margins=True)
# Out:
# PRODUCTO          CH PROPIA  CH TITU  CONSUMO  MASIVO SUFI  \
# Tipo De Producto
# 1                         0      140        0            0
# 2                      8720        0        0            0
# 3                         0        0        0            0
# 4                         0        0     9232            0
# 5                         0        0     2118            0
# 6                         0        0     1956            0
# 14                        0        0        0            3
# 15                        0        0        0           50
# 16                        0        0        0            0
# 20                        0        0        0         1511
# 24                        0        0        0            3
# 25                        0        0        0          268
# 27                        0        0        0            0
# 45                        0        0        0           29
# 46                        0        0        0           79
# 47                        0        0        0           83
# 80                        0        0        0           26
# 85                        0        0        7            0
# 86                        0        0      440            0
# 87                        0        0        6            0
# 88                        0        0     4314            0
# 89                        0        0     1551            0
# 94                        0        0        0          890
# All                    8720      140    19624         2942
#
# PRODUCTO          TARJETAS DE CREDITO  VEHICULOS SUFI    All
# Tipo De Producto
# 1                                   0               0    140
# 2                                   0               0   8720
# 3                               51864               0  51864
# 4                                   0               0   9232
# 5                                   0               0   2118
# 6                                   0               0   1956
# 14                                  0               0      3
# 15                                  0               0     50
# 16                                  0            5889   5889
# 20                                  0               0   1511
# 24                                  0               0      3
# 25                                  0               0    268
# 27                                  0              68     68
# 45                                  0               0     29
# 46                                  0               0     79
# 47                                  0               0     83
# 80                                  0               0     26
# 85                                  0               0      7
# 86                                  0               0    440
# 87                                  0               0      6
# 88                                  0               0   4314
# 89                                  0               0   1551
# 94                                  0               0    890
# All                             51864            5957  89247

# %%
pd.crosstab(data["Cuadrante"],data["Ocupacion"],margins=True)
# Out:
# Ocupacion                                  AMA DE CASA  EMPLEADO BANCOLOMBIA  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD               0                     1
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                  8                     2
# SIN CUADRANTE                                        0                     0
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                  0                     1
# TIENE VOLUNTAD Y TIENE CAPACIDAD                    29                     5
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA           47                     0
# All                                                 84                     9
#
# Ocupacion                                  EMPLEADO FILIAL  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                   0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                      3
# SIN CUADRANTE                                            0
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                      0
# TIENE VOLUNTAD Y TIENE CAPACIDAD                        10
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA               29
# All                                                     42
#
# Ocupacion                                  EMPLEADO SECTOR PRIVADO  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                          34
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                            952
# SIN CUADRANTE                                                    1
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                            121
# TIENE VOLUNTAD Y TIENE CAPACIDAD                              6424
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                     6567
# All                                                          14099
#
# Ocupacion                                  EMPLEADO SECTOR PUBLICO  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                           8
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                            373
# SIN CUADRANTE                                                    1
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                             40
# TIENE VOLUNTAD Y TIENE CAPACIDAD                              1924
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                     2389
# All                                                           4735
#
# Ocupacion                                  INDEPENDIENTE  JUBILADO  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                 6         0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                  925       126
# SIN CUADRANTE                                          1         0
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                  114        23
# TIENE VOLUNTAD Y TIENE CAPACIDAD                    4632       284
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA           5720       490
# All                                                11398       923
#
# Ocupacion                                  NO APLICA A ESTE PRODUCTO  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                             0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                               59
# SIN CUADRANTE                                                      0
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                                5
# TIENE VOLUNTAD Y TIENE CAPACIDAD                                 218
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                        375
# All                                                              657
#
# Ocupacion                                  SIN OFICIO  TAXISTA  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD              7        0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD              3323        2
# SIN CUADRANTE                                   20997        0
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD               260        0
# TIENE VOLUNTAD Y TIENE CAPACIDAD                13471       25
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA       17466       36
# All                                             55524       63
#
# Ocupacion                                  TRABAJADOR OFICIAL    All
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                      0     56
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                        10   5783
# SIN CUADRANTE                                               0  21000
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                         0    564
# TIENE VOLUNTAD Y TIENE CAPACIDAD                           32  27054
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                  32  33151
# All                                                        74  87608

# %%
pd.crosstab(data["Cuadrante"],data["Descripcion Causal"],margins=True)
# Out:
# Descripcion Causal                         ACOSTUMBRA A PAGAR ATRASADO  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                               2
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                                 38
# SIN CUADRANTE                                                       55
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                                 10
# TIENE VOLUNTAD Y TIENE CAPACIDAD                                   347
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                          205
# All                                                                657
#
# Descripcion Causal                         AFECTADO POR ESTAFA  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                       0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                          4
# SIN CUADRANTE                                                0
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                          4
# TIENE VOLUNTAD Y TIENE CAPACIDAD                            10
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                   49
# All                                                         67
#
# Descripcion Causal                         AFECTADO POR PIRAMIDES  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                          0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                             1
# SIN CUADRANTE                                                   0
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                             0
# TIENE VOLUNTAD Y TIENE CAPACIDAD                               13
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                       6
# All                                                            20
#
# Descripcion Causal                         APARENTE FRAUDE  CALAMIDAD  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                   0          3
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                      0        270
# SIN CUADRANTE                                            0         26
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                      0         49
# TIENE VOLUNTAD Y TIENE CAPACIDAD                         6       1040
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                9       2677
# All                                                     15       4065
#
# Descripcion Causal                         CAMBIOS CLIMATICOS O FALLA HUMANA  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                                     0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                                        5
# SIN CUADRANTE                                                              3
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                                        0
# TIENE VOLUNTAD Y TIENE CAPACIDAD                                          14
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                                 52
# All                                                                       74
#
# Descripcion Causal                         CHEQUE DEVUELTO POR LA ENTIDAD  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                                  0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                                    10
# SIN CUADRANTE                                                           0
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                                     0
# TIENE VOLUNTAD Y TIENE CAPACIDAD                                       63
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                              33
# All                                                                   106
#
# Descripcion Causal                         CLIENTE NO INFORMA CAUSAL  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                             0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                               55
# SIN CUADRANTE                                                     16
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                                3
# TIENE VOLUNTAD Y TIENE CAPACIDAD                                 676
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                        228
# All                                                              978
#
# Descripcion Causal                         CUENTAS POR COBRAR  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                     10
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                       452
# SIN CUADRANTE                                              90
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                        77
# TIENE VOLUNTAD Y TIENE CAPACIDAD                         2680
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                4476
# All                                                      7785
#
# Descripcion Causal                         Condiciones diferentes a las incialmente pactadas  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                                                     1
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                                                        9
# SIN CUADRANTE                                                                              0
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                                                        5
# TIENE VOLUNTAD Y TIENE CAPACIDAD                                                          26
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                                                172
# All                                                                                      213
#
# Descripcion Causal                         ...  SIN CAUSAL DE MORA  \
# Cuadrante                                  ...
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD     ...                   0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD        ...                   1
# SIN CUADRANTE                              ...               20239
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD        ...                   1
# TIENE VOLUNTAD Y TIENE CAPACIDAD           ...                   6
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA  ...                  15
# All                                        ...               20262
#
# Descripcion Causal                         SOBREENDEUDAMIENTO  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                      0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                        96
# SIN CUADRANTE                                               9
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                        31
# TIENE VOLUNTAD Y TIENE CAPACIDAD                          363
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                1062
# All                                                      1561
#
# Descripcion Causal                         TRAMITE REESTRUCTURACION - ACUERDO DE PAGO  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                                              0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                                                 0
# SIN CUADRANTE                                                                       0
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                                                 0
# TIENE VOLUNTAD Y TIENE CAPACIDAD                                                    0
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                                           6
# All                                                                                 6
#
# Descripcion Causal                         TRAMITE SUBROGACION  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                       0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                          0
# SIN CUADRANTE                                                0
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                          0
# TIENE VOLUNTAD Y TIENE CAPACIDAD                             1
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                    1
# All                                                          2
#
# Descripcion Causal                         Titular de un credito pagado por un tercero  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                                               0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                                                 21
# SIN CUADRANTE                                                                        0
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                                                  1
# TIENE VOLUNTAD Y TIENE CAPACIDAD                                                    37
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                                          110
# All                                                                                169
#
# Descripcion Causal                         Titular y/o  Cotitular fallecido  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                                    0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                                       0
# SIN CUADRANTE                                                             0
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                                       0
# TIENE VOLUNTAD Y TIENE CAPACIDAD                                          1
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                                11
# All                                                                      12
#
# Descripcion Causal                         VENTA A TERCERO  VIAJE  \
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                   0      0
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                      0     18
# SIN CUADRANTE                                            1     10
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                      0      5
# TIENE VOLUNTAD Y TIENE CAPACIDAD                         5    385
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA               10    281
# All                                                     16    699
#
# Descripcion Causal                         Victima por conflicto    All
# Cuadrante
# NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD                         0     56
# NO TIENE VOLUNTAD Y TIENE CAPACIDAD                            1   5784
# SIN CUADRANTE                                                  0  20999
# TIENE VOLUNTAD Y NO TIENE CAPACIDAD                            1    561
# TIENE VOLUNTAD Y TIENE CAPACIDAD                               1  27071
# TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA                      8  33152
# All                                                           11  87623
#
# [7 rows x 54 columns]

# %%
pd.crosstab(data["Ocupacion"],data["Descripcion Causal"],margins=True)
# Out:
# Descripcion Causal         ACOSTUMBRA A PAGAR ATRASADO  AFECTADO POR ESTAFA  \
# Ocupacion
# AMA DE CASA                                          1                    0
# EMPLEADO BANCOLOMBIA                                 0                    0
# EMPLEADO FILIAL                                      0                    0
# EMPLEADO SECTOR PRIVADO                            117                    4
# EMPLEADO SECTOR PUBLICO                             27                    1
# INDEPENDIENTE                                       97                   19
# JUBILADO                                             3                    3
# NO APLICA A ESTE PRODUCTO                            7                    0
# SIN OFICIO                                         435                   40
# TAXISTA                                              1                    0
# TRABAJADOR OFICIAL                                   0                    0
# All                                                688                   67
#
# Descripcion Causal         AFECTADO POR PIRAMIDES  APARENTE FRAUDE  CALAMIDAD  \
# Ocupacion
# AMA DE CASA                                     0                0          7
# EMPLEADO BANCOLOMBIA                            0                0          0
# EMPLEADO FILIAL                                 0                0          3
# EMPLEADO SECTOR PRIVADO                         2                5        960
# EMPLEADO SECTOR PUBLICO                         0                2        393
# INDEPENDIENTE                                   2                2        665
# JUBILADO                                        0                0        158
# NO APLICA A ESTE PRODUCTO                       0                1         36
# SIN OFICIO                                     15                5       1858
# TAXISTA                                         1                0          5
# TRABAJADOR OFICIAL                              0                0          4
# All                                            20               15       4089
#
# Descripcion Causal         CAMBIOS CLIMATICOS O FALLA HUMANA  \
# Ocupacion
# AMA DE CASA                                                0
# EMPLEADO BANCOLOMBIA                                       0
# EMPLEADO FILIAL                                            0
# EMPLEADO SECTOR PRIVADO                                    1
# EMPLEADO SECTOR PUBLICO                                    0
# INDEPENDIENTE                                             39
# JUBILADO                                                   1
# NO APLICA A ESTE PRODUCTO                                  0
# SIN OFICIO                                                33
# TAXISTA                                                    0
# TRABAJADOR OFICIAL                                         0
# All                                                       74
#
# Descripcion Causal         CHEQUE DEVUELTO POR LA ENTIDAD  \
# Ocupacion
# AMA DE CASA                                             1
# EMPLEADO BANCOLOMBIA                                    0
# EMPLEADO FILIAL                                         0
# EMPLEADO SECTOR PRIVADO                                11
# EMPLEADO SECTOR PUBLICO                                 4
# INDEPENDIENTE                                          12
# JUBILADO                                                1
# NO APLICA A ESTE PRODUCTO                               0
# SIN OFICIO                                            311
# TAXISTA                                                 1
# TRABAJADOR OFICIAL                                      0
# All                                                   341
#
# Descripcion Causal         CLIENTE NO INFORMA CAUSAL  CUENTAS POR COBRAR  \
# Ocupacion
# AMA DE CASA                                        1                  11
# EMPLEADO BANCOLOMBIA                               0                   1
# EMPLEADO FILIAL                                    0                   5
# EMPLEADO SECTOR PRIVADO                          151                1249
# EMPLEADO SECTOR PUBLICO                           54                 397
# INDEPENDIENTE                                     96                2697
# JUBILADO                                           4                  93
# NO APLICA A ESTE PRODUCTO                         10                  77
# SIN OFICIO                                       669                3327
# TAXISTA                                            0                  11
# TRABAJADOR OFICIAL                                 1                   8
# All                                              986                7876
#
# Descripcion Causal         Condiciones diferentes a las incialmente pactadas  \
# Ocupacion
# AMA DE CASA                                                                0
# EMPLEADO BANCOLOMBIA                                                       0
# EMPLEADO FILIAL                                                            0
# EMPLEADO SECTOR PRIVADO                                                   25
# EMPLEADO SECTOR PUBLICO                                                   11
# INDEPENDIENTE                                                             41
# JUBILADO                                                                   6
# NO APLICA A ESTE PRODUCTO                                                  2
# SIN OFICIO                                                               126
# TAXISTA                                                                    3
# TRABAJADOR OFICIAL                                                         0
# All                                                                      214
#
# Descripcion Causal         ...  SIN CAUSAL DE MORA  SOBREENDEUDAMIENTO  \
# Ocupacion                  ...
# AMA DE CASA                ...                   0                   0
# EMPLEADO BANCOLOMBIA       ...                   0                   2
# EMPLEADO FILIAL            ...                   0                   1
# EMPLEADO SECTOR PRIVADO    ...                   1                 446
# EMPLEADO SECTOR PUBLICO    ...                   0                 151
# INDEPENDIENTE              ...                   1                 218
# JUBILADO                   ...                   0                  53
# NO APLICA A ESTE PRODUCTO  ...                   0                  21
# SIN OFICIO                 ...               20289                 678
# TAXISTA                    ...                   0                   3
# TRABAJADOR OFICIAL         ...                   0                   3
# All                        ...               20291                1576
#
# Descripcion Causal         TRAMITE REESTRUCTURACION - ACUERDO DE PAGO  \
# Ocupacion
# AMA DE CASA                                                         0
# EMPLEADO BANCOLOMBIA                                                0
# EMPLEADO FILIAL                                                     0
# EMPLEADO SECTOR PRIVADO                                             3
# EMPLEADO SECTOR PUBLICO                                             0
# INDEPENDIENTE                                                       0
# JUBILADO                                                            0
# NO APLICA A ESTE PRODUCTO                                           0
# SIN OFICIO                                                          3
# TAXISTA                                                             0
# TRABAJADOR OFICIAL                                                  0
# All                                                                 6
#
# Descripcion Causal         TRAMITE SUBROGACION  \
# Ocupacion
# AMA DE CASA                                  0
# EMPLEADO BANCOLOMBIA                         0
# EMPLEADO FILIAL                              0
# EMPLEADO SECTOR PRIVADO                      2
# EMPLEADO SECTOR PUBLICO                      0
# INDEPENDIENTE                                0
# JUBILADO                                     0
# NO APLICA A ESTE PRODUCTO                    0
# SIN OFICIO                                   0
# TAXISTA                                      0
# TRABAJADOR OFICIAL                           0
# All                                          2
#
# Descripcion Causal         Titular de un credito pagado por un tercero  \
# Ocupacion
# AMA DE CASA                                                          0
# EMPLEADO BANCOLOMBIA                                                 0
# EMPLEADO FILIAL                                                      1
# EMPLEADO SECTOR PRIVADO                                             40
# EMPLEADO SECTOR PUBLICO                                              9
# INDEPENDIENTE                                                       34
# JUBILADO                                                             1
# NO APLICA A ESTE PRODUCTO                                            1
# SIN OFICIO                                                          87
# TAXISTA                                                              0
# TRABAJADOR OFICIAL                                                   1
# All                                                                174
#
# Descripcion Causal         Titular y/o  Cotitular fallecido  VENTA A TERCERO  \
# Ocupacion
# AMA DE CASA                                               0                0
# EMPLEADO BANCOLOMBIA                                      0                0
# EMPLEADO FILIAL                                           0                0
# EMPLEADO SECTOR PRIVADO                                   1                8
# EMPLEADO SECTOR PUBLICO                                   0                0
# INDEPENDIENTE                                             0                1
# JUBILADO                                                  0                0
# NO APLICA A ESTE PRODUCTO                                 0                1
# SIN OFICIO                                               11                6
# TAXISTA                                                   0                0
# TRABAJADOR OFICIAL                                        0                0
# All                                                      12               16
#
# Descripcion Causal         VIAJE  Victima por conflicto    All
# Ocupacion
# AMA DE CASA                    0                      1     86
# EMPLEADO BANCOLOMBIA           0                      0     10
# EMPLEADO FILIAL                0                      0     42
# EMPLEADO SECTOR PRIVADO      153                      1  14410
# EMPLEADO SECTOR PUBLICO       65                      0   4811
# INDEPENDIENTE                153                      5  11518
# JUBILADO                       8                      0    911
# NO APLICA A ESTE PRODUCTO      3                      0    666
# SIN OFICIO                   346                      4  56211
# TAXISTA                        0                      0     64
# TRABAJADOR OFICIAL             0                      0     74
# All                          728                     11  88803
#
# [12 rows x 54 columns]

# %%
import missingno as msn
msn.matrix(data)
# Out:
# <AxesSubplot:>

# %%
data.drop(columns='Nombres', axis=1, inplace=True)

# %%
data.drop(columns="Numero Documento", axis=1, inplace=True)

# %%
data
# Out:
#        Consecutivo Documento Deudor     Nit  Tipo De Producto  \
# 0                          28768192      18                 3
# 1                           2712044      22                 5
# 2                          13587837      23                 3
# 3                          23479925      46                 3
# 4                           2712382      92                 5
# ...                             ...     ...               ...
# 89242                      24892452  787457                89
# 89243                      24485118  787459                 4
# 89244                      27364653  787459                88
# 89245                      28482366  787459                88
# 89246                      27641335  787459                88
#
#                   PRODUCTO  Valor Obligacion  Valor Vencido  Regional  REGION  \
# 0      TARJETAS DE CREDITO         5637605.0       152093.0      2099  BOGOTA
# 1                  CONSUMO           40584.0        40584.0      2099  BOGOTA
# 2      TARJETAS DE CREDITO         2786178.0       547088.0      3099     SUR
# 3      TARJETAS DE CREDITO         5904653.0      1455631.0      2099  BOGOTA
# 4                  CONSUMO         2221125.0      2221125.0      6399  CENTRO
# ...                    ...               ...            ...       ...     ...
# 89242              CONSUMO         2048599.0       284377.0      3099     SUR
# 89243              CONSUMO        33835903.0      2790040.0      3099     SUR
# 89244              CONSUMO         1540300.0      1511822.0      3099     SUR
# 89245              CONSUMO         3954718.0       609495.0      3099     SUR
# 89246              CONSUMO         2172488.0       350295.0      3099     SUR
#
#        Abogado  Dias Mora  ... Red                                  Cuadrante  \
# 0       109978         30  ...   1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 1       109976        110  ...   1                              SIN CUADRANTE
# 2       109978         60  ...   1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 3       109978         90  ...   1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
# 4       109978         48  ...   1           TIENE VOLUNTAD Y TIENE CAPACIDAD
# ...        ...        ...  ...  ..                                        ...
# 89242   109976         95  ...   1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 89243   109976        104  ...   1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
# 89244   109976        107  ...   1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
# 89245   109976        107  ...   1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
# 89246   109976        107  ...   1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
#
#                       Descripcion Causal Calificacion Real  \
# 0                              CALAMIDAD                 2
# 1                     SIN CAUSAL DE MORA                 3
# 2             RETRASO EN PAGO DE SALARIO                 1
# 3                               DESCUIDO                 1
# 4                               DESCUIDO                 2
# ...                                  ...               ...
# 89242                           DESCUIDO                 3
# 89243  DESEMPLEADO TITULAR Y/O COTITULAR                 3
# 89244  DESEMPLEADO TITULAR Y/O COTITULAR                 3
# 89245  DESEMPLEADO TITULAR Y/O COTITULAR                 3
# 89246  DESEMPLEADO TITULAR Y/O COTITULAR                 3
#
#        Fecha De Perfeccionamiento  Endeudamiento  Rango endeudamiento  \
# 0                      1978-12-06     5637605.00  2015-01-01 00:00:00
# 1                      2015-03-11       40584.00                  <1M
# 2                      2003-03-27     7747280.00  2015-01-01 00:00:00
# 3                      1990-09-01     5904653.00  2015-01-01 00:00:00
# 4                      2015-05-12     2221125.00  2015-01-01 00:00:00
# ...                           ...            ...                  ...
# 89242                  2013-05-27    37088351.03                15-50
# 89243                  2013-03-18    45757681.00                15-50
# 89244                  2014-06-03    45757681.00                15-50
# 89245                  2014-09-29    45757681.00                15-50
# 89246                  2014-07-22    45757681.00                15-50
#
#       Sector Economico      Profesion                Ocupacion
# 0                  NaN  SIN PROFESION               SIN OFICIO
# 1                  NaN  SIN PROFESION               SIN OFICIO
# 2                  NaN  SIN PROFESION                 JUBILADO
# 3                  NaN  SIN PROFESION               SIN OFICIO
# 4         AGROPECUARIO     AGRICULTOR                  TAXISTA
# ...                ...            ...                      ...
# 89242        EDUCACION       PROFESOR  EMPLEADO SECTOR PUBLICO
# 89243              NaN  SIN PROFESION               SIN OFICIO
# 89244              NaN  SIN PROFESION               SIN OFICIO
# 89245              NaN  SIN PROFESION               SIN OFICIO
# 89246              NaN  SIN PROFESION               SIN OFICIO
#
# [89247 rows x 25 columns]

# %%
data.shape
# Out:
# (89247, 27)
